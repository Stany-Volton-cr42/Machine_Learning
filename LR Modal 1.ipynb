# %% [markdown]
# # 1. Import library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# import seaborn as sns

# %%
ir = pd.read_csv('iris.csv')

# %% [markdown]
# ## 2. Cheak head,info and describe

# %%
irs = ir.rename(columns = {'class':'Species'}, inplace = True)

# %%
ir.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
ir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
ir.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### cheak missing values

# %% [markdown]
# # Explore data analysis (EDA)

# %%
ir[ir['sepal_width']>4 ] #versicolor  setosa  virginica
# this data show me the sepal_width of virginica and versicolor is less than 4
# because only setosa have more than 4 sepal_width
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      Species
# 15           5.7          4.4           1.5          0.4  Iris-setosa
# 32           5.2          4.1           1.5          0.1  Iris-setosa
# 33           5.5          4.2           1.4          0.2  Iris-setosa

# %%
ir[ir['petal_width']>1 ]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          Species
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 51            6.4          3.2           4.5          1.5  Iris-versicolor
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 145           6.7          3.0           5.2          2.3   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 148           6.2          3.4           5.4          2.3   Iris-virginica
# 149           5.9          3.0           5.1          1.8   Iris-virginica
#
# [93 rows x 5 columns]

# %%
ir[ir['petal_width']>2 ]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         Species
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 112           6.8          3.0           5.5          2.1  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 115           6.4          3.2           5.3          2.3  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# 124           6.7          3.3           5.7          2.1  Iris-virginica
# ...

# %%
ir.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# Species         0
# dtype: int64

# %% [markdown]
# ## Data Visulazation

# %%
# we want to know the relationship between sepal_length and petal_lengrh
sns.scatterplot(x = 'sepal_length',y = 'petal_length',data = ir,hue='Species')
plt.show()

# %% [markdown]
# ### giving variable

# %%
# we want to know how to sapel_length very with sapel_width
# dependent variable
y = ir[['sepal_length']]

# %%
# independent variable
x = ir[['sepal_width','petal_length','petal_width']]

# %% [markdown]
# ## split train test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_test
# Out:
#      sepal_width  petal_length  petal_width
# 16           3.9           1.3          0.4
# 30           3.1           1.6          0.2
# 112          3.0           5.5          2.1
# 1            3.0           1.4          0.2
# 70           3.2           4.8          1.8
# 106          2.5           4.5          1.7
# 110          3.2           5.1          2.0
# 141          3.1           5.1          2.3
# 146          2.5           5.0          1.9
# 79           2.6           3.5          1.0
# 11           3.4           1.6          0.2
# 12           3.0           1.4          0.1
# 50           3.2           4.7          1.4
# 144          3.3           5.7          2.5
# 34           3.1           1.5          0.1
# 22           3.6           1.0          0.2
# 102          3.0           5.9          2.1
# 107          2.9           6.3          1.8
# 14           4.0           1.2          0.2
# 19           3.8           1.5          0.3
# ...

# %%
y_train
# Out:
#      sepal_length
# 143           6.8
# 49            5.0
# 28            5.2
# 43            5.0
# 25            5.0
# ..            ...
# 56            6.3
# 39            5.1
# 135           7.7
# 140           6.7
# 68            6.2
#
# [120 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
Lr = LinearRegression()

# %%
Lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ###  prediction

# %%
y_predict = Lr.predict(x_test)

# %%
y_test.head()
# Out:
#      sepal_length
# 16            5.4
# 30            4.8
# 112           6.8
# 1             4.9
# 70            5.9

# %%
y_predict[:5]
# Out:
# array([[5.06326133],
#        [4.90935426],
#        [6.51385487],
#        [4.70394781],
#        [6.31277999]])

# %% [markdown]
# ### error

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 0.11680379961341444

# %% [markdown]
# ### equiricy

# %%
from sklearn.metrics import r2_score , accuracy_score
from sklearn import metrics

# %%
metrics.r2_score(y_test,y_predict)
# Out:
# 0.8375443606730547
